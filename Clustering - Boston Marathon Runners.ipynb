# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import math
import scipy
import scipy.stats as stats
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
runners = pd.read_csv('/Users/Albert/Desktop/Thinkful_Drills/Data/Unsupervised Learning/Boston Marathon Results - 2014.csv')
runners.head()
# Out:
#      10k                name  division    25k gender  age  official bib  \
# 0  17.37  Yamamoto, Hiroyuki         8  47.67      M   47     85.25  W1
# 1  32.58        Jeptoo, Rita         1  82.43      F   33    138.95  F1
# 2  16.62   Van Dyk, Ernst F.         1  45.80      M   41     80.60  W2
# 3  32.57        Dibaba, Mare         3  82.43      F   24    140.58  F2
# 4  17.12      Hokinoue, Kota         2  46.37      M   40     81.23  W3
#
#    genderdiv  ctz   ...   overall  pace  state    30k     5k   half    20k  \
# 0          8  NaN   ...         8  3.27    NaN  59.18   8.02  39.72  37.65
# 1          1  NaN   ...        21  5.30    NaN  99.33  16.22  69.47  65.83
# 2          1  NaN   ...         1  3.08    NaN  56.45   7.75  38.03  36.10
# 3          3  NaN   ...        27  5.37    NaN  99.33  16.20  69.47  65.83
# 4          2  NaN   ...         2  3.10    NaN  57.03   8.02  38.60  36.58
#
#   country            city     40k
# 0     JPN         Fukuoka   80.43
# ...

# %%
print(runners.shape)
for col in runners.columns:
    print (col)
# Out:
# (31984, 21)
# 10k
# name
# division
# 25k
# gender
# age
# official
# bib
# genderdiv
# ctz
# 35k
# overall
# pace
# state
# 30k
# 5k
# half
# 20k
# country
# city
# 40k

# %%
del runners['bib']
del runners['ctz']

# %%
# Out:
# nan

# %%
def null_conv (x):
    if '-' in x:
        return runners['state'].iloc[0]

runners.apply(null_conv, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
#          ...
# 31954    None
# 31955    None
# 31956    None
# 31957    None
# 31958    None
# 31959    None
# 31960    None
# 31961    None
# 31962    None
# 31963    None
# 31964    None
# 31965    None
# 31966    None
# 31967    None
# 31968    None
# 31969    None
# 31970    None
# 31971    None
# 31972    None
# 31973    None
# 31974    None
# 31975    None
# 31976    None
# 31977    None
# 31978    None
# 31979    None
# 31980    None
# 31981    None
# 31982    None
# 31983    None
# ...

# %%
runners
# Out:
#          10k                        name  division     25k gender  age  \
# 0      17.37          Yamamoto, Hiroyuki         8   47.67      M   47
# 1      32.58                Jeptoo, Rita         1   82.43      F   33
# 2      16.62           Van Dyk, Ernst F.         1   45.80      M   41
# 3      32.57                Dibaba, Mare         3   82.43      F   24
# 4      17.12              Hokinoue, Kota         2   46.37      M   40
# 5      32.58     Sumgong, Jemima Jelagat         4   82.45      F   29
# 6      17.65              Hug, Marcel E.         4   47.67      M   28
# 7      30.48              Geneti, Markos         5   76.95      M   29
# 8      17.12           Soejima, Masazumi         3   46.37      M   43
# 9      30.48                  Hall, Ryan        20   77.68      M   31
# 10     32.58              Cherop, Sharon         8   82.45      F   30
# 11     30.52              Chebet, Wilson         2   76.97      M   28
# ...

# %%
str_to_num = ['5k','10k','20k','25k','30k','35k','40k','half']

for col in str_to_num:
    runners[col] = pd.to_numeric(runners[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-51fb5a0fb824> in <module>()
#       2
#       3 for col in str_to_num:
# ----> 4     runners[col] = pd.to_numeric(runners[col])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# ...

# %%
runners.iloc[835:837]
# Out:
#        10k                  name  division     25k gender       age  official  \
# 835  43.35          Takacs, Greg      3313  112.05      M  (34, 44]    209.23
# 836  38.28  Moosbrugger, Michael      2701  100.75      M  (24, 34]    194.87
#
#      genderdiv     35k  overall  pace state     30k     5k   half    20k  \
# 835       7094  167.47     9079  7.98    TX  137.70  21.38  93.58  88.45
# 836       4672  150.93     5252  7.43   NaN  124.67      -  83.70  79.12
#
#     country         city     40k
# 835     USA  Willow Park  198.00
# 836     AUT     Dornbirn  181.07

# %%
runners['official'].dtype
# Out:
# dtype('float64')

# %%
runners['division'].describe()
# Out:
# count    31984.000000
# mean      1932.563032
# std       1715.228694
# min          1.000000
# 25%        610.000000
# 50%       1425.000000
# 75%       2611.000000
# max       6979.000000
# Name: division, dtype: float64

# %%
runners['age'] = pd.cut(runners['age'], [17,24,34,44,59,69,82])

# %%
time_features = runners[['5k','10k','20k','25k','30k','35k','40k','half','official','pace','overall']]
catg_features = runners[['gender','age','country']]
features = pd.concat([time_features, catg_features], axis=1)

# %%
Xgen = pd.get_dummies(features.drop(labels='gender', axis=1))
Ygen = pd.get_dummies(features['gender'])

Xage = pd.get_dummies(features.drop(labels='age', axis=1))
Yage = pd.get_dummies(features['age'])

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
